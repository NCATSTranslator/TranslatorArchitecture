# %%
import requests

# %%
def post(url, message, params=None):
    if params is None:
        response = requests.post(url, json=message)
    else:
        response = requests.post(url, json=message, params=params)
    if not response.status_code == 200:
        print('error:', response.status_code)
        return {}
    return response.json()

# %%
def get_ontology_descendents(curie,btype):
    m ={
    "message": {
        "query_graph": {
            "nodes": {
                "a": {
                    "id": curie
                },
                "b": {
                    "category": btype
                }
            },
            "edges": {
                "ab": {
                    "subject": "b",
                    "object": "a",
                    "predicate": "biolink:subclass_of"
                }
            }
        }}}
    url = 'https://stars-app.renci.org/sparql-kp/query'
    response = post(url,m)
    nodes = response['message']['knowledge_graph']['nodes']
    tnodes = [ {"identifier":k, "label": v['name']} for k,v in nodes.items()]
    return {curie: tnodes}

# %%
def convert_to_preferred(curie,allowedlist):
    j = {'curies':[curie]}
    result = post('https://nodenormalization-sri.renci.org/get_normalized_nodes',j)
    new_ids = [ v['identifier'] for v in result[curie]['equivalent_identifiers'] ]
    for nid in new_ids:
        if nid.split(':')[0] in allowedlist:
            return nid
    return None

# %%
m = 'MONDO:0005015'

# %%
get_ontology_descendents(m,'biolink:Disease')
# Out:
# {'MONDO:0005015': [{'identifier': 'MONDO:0011572',
#    'label': 'type 1 diabetes mellitus 18'},
#   {'identifier': 'MONDO:0011068', 'label': 'type 1 diabetes mellitus 12'},
#   {'identifier': 'MONDO:0011123', 'label': 'type 1 diabetes mellitus 15'},
#   {'identifier': 'MONDO:0018573',
#    'label': 'intrauterine growth restriction-short stature-early adult-onset diabetes syndrome'},
#   {'identifier': 'MONDO:0019193',
#    'label': 'acquired generalized lipodystrophy'},
#   {'identifier': 'MONDO:0012919', 'label': 'type 1 diabetes mellitus 20'},
#   {'identifier': 'MONDO:0015967', 'label': 'monogenic diabetes'},
#   {'identifier': 'MONDO:0010020',
#    'label': 'congenital generalized lipodystrophy type 2'},
#   {'identifier': 'MONDO:0018581',
#    'label': 'progressive encephalomyelitis with rigidity and myoclonus'},
#   {'identifier': 'MONDO:0009100', 'label': 'IDDM 1'},
#   {'identifier': 'MONDO:0030089',
#    'label': 'diabetes mellitus, permanent neonatal 4'},
#   {'identifier': 'MONDO:0018625', 'label': 'classic stiff person syndrome'},
#   {'identifier': 'MONDO:0011273', 'label': 'H syndrome'},
#   {'identifier': 'MONDO:0010864', 'label': 'type 1 diabetes mellitus 7'},
#   {'identifier': 'MONDO:0020525',
#    'label': 'transient neonatal diabetes mellitus (disease)'},
#   {'identifier': 'MONDO:0009419', 'label': 'Woodhouse-Sakati syndrome'},
#   {'identifier': 'MONDO:0010802',
#    'label': 'pancreatic hypoplasia-diabetes-congenital heart disease syndrome'},
#   {'identifier': 'MONDO:0012071',
#    'label': 'congenital generalized lipodystrophy type 1'},
#   {'identifier': 'MONDO:0012522',
#    'label': 'diabetes mellitus, transient neonatal, 3'},
#   {'identifier': 'MONDO:0014686',
#    'label': 'short stature, microcephaly, and endocrine dysfunction'},
#   {'identifier': 'MONDO:0012920', 'label': 'type 1 diabetes mellitus 21'},
#   {'identifier': 'MONDO:0011027',
#    'label': 'diabetes mellitus, noninsulin-dependent, 1'},
#   {'identifier': 'MONDO:0016464',
#    'label': 'insulin-resistance syndrome type B'},
#   {'identifier': 'MONDO:0018911',
#    'label': 'maturity-onset diabetes of the young (disease)'},
#   {'identifier': 'MONDO:0010950', 'label': 'type 1 diabetes mellitus 8'},
#   {'identifier': 'MONDO:0011363',
#    'label': 'diabetes mellitus, noninsulin-dependent, 3'},
#   {'identifier': 'MONDO:0014458',
#    'label': 'Fanconi renotubular syndrome 4 with maturity-onset diabetes of the young'},
#   {'identifier': 'MONDO:0014523',
#    'label': 'juvenile-onset diabetes mellitus-central and peripheral neurodegeneration syndrome'},
#   {'identifier': 'MONDO:0010255',
#    'label': 'diabetes mellitus, insulin-dependent, X-linked, susceptibility to'},
#   {'identifier': 'MONDO:0011072',
#    'label': 'diabetes mellitus, noninsulin-dependent, 2'},
#   {'identifier': 'MONDO:0016422',
#    'label': 'autoimmune polyendocrinopathy type 3'},
#   {'identifier': 'MONDO:0011033', 'label': 'type 1 diabetes mellitus 13'},
#   {'identifier': 'MONDO:0014589',
#    'label': 'maturity-onset diabetes of the young type 13'},
#   {'identifier': 'MONDO:0010026', 'label': 'SHORT syndrome'},
#   {'identifier': 'MONDO:0100165',
#    'label': 'permanent neonatal diabetes mellitus 1'},
#   {'identifier': 'MONDO:0012819', 'label': 'diabetic ketoacidosis'},
#   {'identifier': 'MONDO:0011955',
#    'label': 'diabetes mellitus, noninsulin-dependent, 4'},
#   {'identifier': 'MONDO:0008185', 'label': 'hereditary chronic pancreatitis'},
#   {'identifier': 'MONDO:0014497',
#    'label': 'polyendocrine-polyneuropathy syndrome'},
#   {'identifier': 'MONDO:0008491', 'label': 'stiff-person syndrome'},
#   {'identifier': 'MONDO:0010862', 'label': 'type 1 diabetes mellitus 4'},
#   {'identifier': 'MONDO:0009517', 'label': 'Donohue syndrome'},
#   {'identifier': 'MONDO:0012923',
#    'label': 'congenital generalized lipodystrophy type 3'},
#   {'identifier': 'MONDO:0014674',
#    'label': 'maturity-onset diabetes of the young type 14'},
#   {'identifier': 'MONDO:0012422', 'label': 'type 1 diabetes mellitus 19'},
#   {'identifier': 'MONDO:0011986', 'label': 'tropical pancreatitis'},
#   {'identifier': 'MONDO:0009192', 'label': 'Wolcott-Rallison syndrome'},
#   {'identifier': 'MONDO:0012818',
#    'label': 'maturity-onset diabetes of the young type 9'},
#   {'identifier': 'MONDO:0013242',
#    'label': 'maturity-onset diabetes of the young type 11'},
#   {'identifier': 'MONDO:0012436',
#    'label': 'neonatal diabetes mellitus with congenital hypothyroidism'},
#   {'identifier': 'MONDO:0005827', 'label': 'lipoatrophic diabetes'},
#   {'identifier': 'MONDO:0011668',
#    'label': 'maturity-onset diabetes of the young type 6'},
#   {'identifier': 'MONDO:0100164',
#    'label': 'permanent neonatal diabetes mellitus'},
#   {'identifier': 'MONDO:0013240',
#    'label': 'maturity-onset diabetes of the young type 10'},
#   {'identifier': 'MONDO:0011167', 'label': 'type 1 diabetes mellitus 6'},
#   {'identifier': 'MONDO:0012480',
#    'label': 'diabetes mellitus, transient neonatal, 2'},
#   {'identifier': 'MONDO:0013078', 'label': 'type 1 diabetes mellitus 24'},
#   {'identifier': 'MONDO:0018320',
#    'label': 'primary microcephaly-mild intellectual disability-young-onset diabetes syndrome'},
#   {'identifier': 'MONDO:0009575',
#    'label': 'thiamine-responsive megaloblastic anemia syndrome'},
#   {'identifier': 'MONDO:0008763', 'label': 'Alstrom syndrome'},
#   {'identifier': 'MONDO:0015308',
#    'label': 'laminopathy type Decaudain-Vigouroux'},
#   {'identifier': 'MONDO:0010773', 'label': 'myopathy and diabetes mellitus'},
#   {'identifier': 'MONDO:0012961', 'label': 'type 1 diabetes mellitus 23'},
#   {'identifier': 'MONDO:0006920', 'label': 'prediabetes syndrome'},
#   {'identifier': 'MONDO:0010861', 'label': 'type 1 diabetes mellitus 3'},
#   {'identifier': 'MONDO:0007452',
#    'label': 'maturity-onset diabetes of the young type 1'},
#   {'identifier': 'MONDO:0020569', 'label': 'intermediate DEND syndrome'},
#   {'identifier': 'MONDO:0018883',
#    'label': 'Berardinelli-Seip congenital lipodystrophy'},
#   {'identifier': 'MONDO:0014488',
#    'label': 'diabetes mellitus, noninsulin-dependent, 5'},
#   {'identifier': 'MONDO:0005147', 'label': 'type 1 diabetes mellitus'},
#   {'identifier': 'MONDO:0011016', 'label': 'type 1 diabetes mellitus 11'},
#   {'identifier': 'MONDO:0018629', 'label': 'focal stiff limb syndrome'},
#   {'identifier': 'MONDO:0005406', 'label': 'gestational diabetes'},
#   {'identifier': 'MONDO:0008696',
#    'label': 'acanthosis nigricans-insulin resistance-muscle cramps-acral enlargement syndrome'},
#   {'identifier': 'MONDO:0011168', 'label': 'type 1 diabetes mellitus 10'},
#   {'identifier': 'MONDO:0010785',
#    'label': 'maternally-inherited diabetes and deafness'},
#   {'identifier': 'MONDO:0007453',
#    'label': 'maturity-onset diabetes of the young type 2'},
#   {'identifier': 'MONDO:0030088',
#    'label': 'diabetes mellitus, permanent neonatal 3'},
#   {'identifier': 'MONDO:0012921', 'label': 'type 1 diabetes mellitus 22'},
#   {'identifier': 'MONDO:0019207', 'label': 'DEND syndrome'},
#   {'identifier': 'MONDO:0013225',
#    'label': 'congenital generalized lipodystrophy type 4'},
#   {'identifier': 'MONDO:0010894',
#    'label': 'maturity-onset diabetes of the young type 3'},
#   {'identifier': 'MONDO:0012513',
#    'label': 'maturity-onset diabetes of the young type 7'},
#   {'identifier': 'MONDO:0014991', 'label': 'Seckel syndrome 10'},
#   {'identifier': 'MONDO:0011302', 'label': 'type 1 diabetes mellitus 17'},
#   {'identifier': 'MONDO:0011667',
#    'label': 'maturity-onset diabetes of the young type 4'},
#   {'identifier': 'MONDO:0011073',
#    'label': 'diabetes mellitus, transient neonatal, 1'},
#   {'identifier': 'MONDO:0008812', 'label': 'AREDYLD syndrome'},
#   {'identifier': 'MONDO:0012520',
#    'label': 'insulin-resistance syndrome type A'},
#   {'identifier': 'MONDO:0007454', 'label': 'type 1 diabetes mellitus 2'},
#   {'identifier': 'MONDO:0013478',
#    'label': 'PLIN1-related familial partial lipodystrophy'},
#   {'identifier': 'MONDO:0005148', 'label': 'type 2 diabetes mellitus'},
#   {'identifier': 'MONDO:0016391', 'label': 'neonatal diabetes mellitus'},
#   {'identifier': 'MONDO:0010863', 'label': 'type 1 diabetes mellitus 5'},
#   {'identifier': 'MONDO:0017230',
#    'label': 'autosomal semi-dominant severe lipodystrophic laminopathy'},
#   {'identifier': 'MONDO:0030087',
#    'label': 'diabetes mellitus, permanent neonatal 2'},
#   {'identifier': 'MONDO:0012348',
#    'label': 'maturity-onset diabetes of the young type 8'},
#   {'identifier': 'MONDO:0005015', 'label': 'diabetes mellitus (disease)'},
#   {'identifier': 'MONDO:0019017',
#    'label': 'short fifth metacarpals-insulin resistance syndrome'},
#   {'identifier': 'MONDO:0007669',
#    'label': 'renal cysts and diabetes syndrome'},
#   {'identifier': 'MONDO:0012192',
#    'label': 'permanent neonatal diabetes mellitus-pancreatic and cerebellar agenesis syndrome'},
#   {'identifier': 'MONDO:0018575',
#    'label': 'microcephalic primordial dwarfism-insulin resistance syndrome'},
#   {'identifier': 'MONDO:0009874', 'label': 'Rabson-Mendenhall syndrome'}]}

# %%
mlist = ['MONDO:0005015', 'MONDO:0005148']
get_ontology_descendents(mlist,'biolink:Disease')
# Out:
# error: 400
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d80e48d195c0> in <module>
#       1 mlist = ['MONDO:0005015', 'MONDO:0005148']
# ----> 2 get_ontology_descendents(mlist,'biolink:Disease')
#
# <ipython-input-19-ffa32c9f137f> in get_ontology_descendents(curie, btype)
#      21     url = 'https://stars-app.renci.org/sparql-kp/query'
#      22     response = post(url,m)
# ---> 23     nodes = response['message']['knowledge_graph']['nodes']
#      24     tnodes = [ {"identifier":k, "label": v['name']} for k,v in nodes.items()]
#      25     return {curie: tnodes}
#
# KeyError: 'message'

# %%
t2d_doid='DOID:1909'

# %%
convert_to_preferred(t2d_doid,['MONDO'])
# Out:
# 'MONDO:0005105'

# %%
mondo_descendents = get_ontology_descendents(m,'biolink:Disease')

# %%
mondo_descendent_ids = [x['identifier'] for x in mondo_descendents['MONDO:0005015']]

# %%
mondo_descendent_ids
# Out:
# ['MONDO:0011572',
#  'MONDO:0011068',
#  'MONDO:0011123',
#  'MONDO:0018573',
#  'MONDO:0019193',
#  'MONDO:0012919',
#  'MONDO:0015967',
#  'MONDO:0010020',
#  'MONDO:0018581',
#  'MONDO:0009100',
#  'MONDO:0030089',
#  'MONDO:0018625',
#  'MONDO:0011273',
#  'MONDO:0010864',
#  'MONDO:0020525',
#  'MONDO:0009419',
#  'MONDO:0010802',
#  'MONDO:0012071',
#  'MONDO:0012522',
#  'MONDO:0014686',
#  'MONDO:0012920',
#  'MONDO:0011027',
#  'MONDO:0016464',
#  'MONDO:0018911',
#  'MONDO:0010950',
#  'MONDO:0011363',
#  'MONDO:0014458',
#  'MONDO:0014523',
#  'MONDO:0010255',
#  'MONDO:0011072',
#  'MONDO:0016422',
#  'MONDO:0011033',
#  'MONDO:0014589',
#  'MONDO:0010026',
#  'MONDO:0100165',
#  'MONDO:0012819',
#  'MONDO:0011955',
#  'MONDO:0008185',
#  'MONDO:0014497',
#  'MONDO:0008491',
#  'MONDO:0010862',
#  'MONDO:0009517',
#  'MONDO:0012923',
#  'MONDO:0014674',
#  'MONDO:0012422',
#  'MONDO:0011986',
#  'MONDO:0009192',
#  'MONDO:0012818',
#  'MONDO:0013242',
#  'MONDO:0012436',
#  'MONDO:0005827',
#  'MONDO:0011668',
#  'MONDO:0100164',
#  'MONDO:0013240',
#  'MONDO:0011167',
#  'MONDO:0012480',
#  'MONDO:0013078',
#  'MONDO:0018320',
#  'MONDO:0009575',
#  'MONDO:0008763',
#  'MONDO:0015308',
#  'MONDO:0010773',
#  'MONDO:0012961',
#  'MONDO:0006920',
#  'MONDO:0010861',
#  'MONDO:0007452',
#  'MONDO:0020569',
#  'MONDO:0018883',
#  'MONDO:0014488',
#  'MONDO:0005147',
#  'MONDO:0011016',
#  'MONDO:0018629',
#  'MONDO:0005406',
#  'MONDO:0008696',
#  'MONDO:0011168',
#  'MONDO:0010785',
#  'MONDO:0007453',
#  'MONDO:0030088',
#  'MONDO:0012921',
#  'MONDO:0019207',
#  'MONDO:0013225',
#  'MONDO:0010894',
#  'MONDO:0012513',
#  'MONDO:0014991',
#  'MONDO:0011302',
#  'MONDO:0011667',
#  'MONDO:0011073',
#  'MONDO:0008812',
#  'MONDO:0012520',
#  'MONDO:0007454',
#  'MONDO:0013478',
#  'MONDO:0005148',
#  'MONDO:0016391',
#  'MONDO:0010863',
#  'MONDO:0017230',
#  'MONDO:0030087',
#  'MONDO:0012348',
#  'MONDO:0005015',
#  'MONDO:0019017',
#  'MONDO:0007669',
#  'MONDO:0012192',
#  'MONDO:0018575',
#  'MONDO:0009874']

# %%
for mid in mondo_descendent_ids:
    print(mid,convert_to_preferred(mid,['DOID']))
# Out:
# MONDO:0011572 DOID:0110755
# MONDO:0011068 DOID:0110751
# MONDO:0011123 DOID:0110753
# MONDO:0018573 None
# MONDO:0019193 DOID:0080300
# MONDO:0012919 DOID:0110757
# MONDO:0015967 None
# MONDO:0010020 DOID:0111136
# MONDO:0018581 None
# MONDO:0009100 None
# MONDO:0030089 None
# MONDO:0018625 None
# MONDO:0011273 None
# MONDO:0010864 DOID:0110746
# MONDO:0020525 DOID:0060334
# MONDO:0009419 None
# MONDO:0010802 DOID:0111733
# MONDO:0012071 DOID:0111135
# MONDO:0012522 None
# MONDO:0014686 None
# MONDO:0012920 DOID:0110758
# MONDO:0011027 None
# MONDO:0016464 None
# MONDO:0018911 DOID:0050524
# MONDO:0010950 DOID:0110747
# MONDO:0011363 None
# MONDO:0014458 None
# MONDO:0014523 None
# MONDO:0010255 None
# MONDO:0011072 None
# MONDO:0016422 None
# MONDO:0011033 DOID:0110752
# MONDO:0014589 DOID:0111110
# MONDO:0010026 DOID:0111454
# MONDO:0100165 None
# MONDO:0012819 DOID:1837
# MONDO:0011955 None
# MONDO:0008185 None
# MONDO:0014497 None
# MONDO:0008491 DOID:13366
# MONDO:0010862 DOID:0110743
# MONDO:0009517 DOID:0050470
# MONDO:0012923 DOID:0111137
# MONDO:0014674 DOID:0111111
# MONDO:0012422 DOID:0110756
# MONDO:0011986 None
# MONDO:0009192 DOID:0090060
# MONDO:0012818 DOID:0111107
# MONDO:0013242 DOID:0111109
# MONDO:0012436 DOID:0060638
# MONDO:0005827 DOID:11712
# MONDO:0011668 DOID:0111104
# MONDO:0100164 DOID:0060639
# MONDO:0013240 DOID:0111108
# MONDO:0011167 DOID:0110745
# MONDO:0012480 None
# MONDO:0013078 DOID:0110761
# MONDO:0018320 None
# MONDO:0009575 DOID:0090117
# MONDO:0008763 DOID:0050473
# MONDO:0015308 None
# MONDO:0010773 None
# MONDO:0012961 DOID:0110760
# MONDO:0006920 DOID:11716
# MONDO:0010861 DOID:0110742
# MONDO:0007452 DOID:0111099
# MONDO:0020569 None
# MONDO:0018883 None
# MONDO:0014488 None
# MONDO:0005147 DOID:9744
# MONDO:0011016 DOID:0110750
# MONDO:0018629 None
# MONDO:0005406 DOID:11714
# MONDO:0008696 None
# MONDO:0011168 DOID:0110749
# MONDO:0010785 None
# MONDO:0007453 DOID:0111100
# MONDO:0030088 None
# MONDO:0012921 DOID:0110759
# MONDO:0019207 None
# MONDO:0013225 DOID:0111138
# MONDO:0010894 DOID:0111102
# MONDO:0012513 DOID:0111106
# MONDO:0014991 DOID:0070008
# MONDO:0011302 DOID:0110754
# MONDO:0011667 DOID:0111103
# MONDO:0011073 None
# MONDO:0008812 None
# MONDO:0012520 None
# MONDO:0007454 DOID:0110741
# MONDO:0013478 DOID:0070205
# MONDO:0005148 DOID:9352
# MONDO:0016391 DOID:11717
# MONDO:0010863 DOID:0110744
# MONDO:0017230 None
# MONDO:0030087 None
# MONDO:0012348 DOID:0111105
# MONDO:0005015 DOID:9351
# MONDO:0019017 None
# MONDO:0007669 DOID:0111101
# MONDO:0012192 None
# MONDO:0018575 None
# MONDO:0009874 None

# %%
import os 
from SPARQLWrapper import SPARQLWrapper2, JSON, POSTDIRECTLY, POST 
from string import Template 
 
 
 
class TripleStore(object): 
    """ Connect to a SPARQL endpoint and provide services for loading and executing queries.""" 
 
    def __init__(self, hostname): 
        self.service =  SPARQLWrapper2 (hostname) 
 
    def get_template (self, query_name): 
        """ Load a template given a template name """ 
        return Template (self.get_template_text (query_name)) 
 
    def get_template_text (self, query_name): 
        """ Get the text of a template given its name """ 
        query = None 
        fn = os.path.join(os.path.dirname(__file__), 'query', 
            '{0}.sparql'.format (query_name)) 
        with open (fn, 'r') as stream: 
            query = stream.read () 
        return query 
     
    def execute_query (self, query, post=False): 
        """ Execute a SPARQL query. 
 
        :param query: A SPARQL query. 
        :return: Returns a JSON formatted object. 
        """ 
        if post: 
            self.service.setRequestMethod(POSTDIRECTLY) 
            self.service.setMethod(POST) 
        self.service.setQuery (query) 
        self.service.setReturnFormat (JSON) 
        return self.service.query().convert () 
     
    def query (self, query_text, outputs, flat=False, post = False): 
        """ Execute a fully formed query and return results. """ 
        response = self.execute_query (query_text, post) 
        result = None 
        if flat: 
            result = list(map(lambda b : [ b[val].value if val in b else None for val in outputs    ], response.bindings )) 
        else: 
            result = list(map(lambda b : { val : b[val].value if val in b else None for val in outputs  }, response.bindings )) 
        return result 
 
    def query_template (self, template_text, outputs, inputs=[], post = False): 
        """ Given template text, inputs, and outputs, execute a query. """ 
        return self.query (Template (template_text).safe_substitute (**inputs), outputs, post= post) 
     
    def query_template_file (self, template_file, outputs, inputs=[]): 
        """ Given the name of a template file, inputs, and outputs, execute a query. """ 
        return self.query (self.get_template_text (template_file), inputs, outputs)

# %%
    def get_subclasses():
        text = """
                PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX mondo: <http://purl.obolibrary.org/obo/MONDO_>
PREFIX biolink: <https://w3id.org/biolink/vocab/>
PREFIX linkml: <https://w3id.org/linkml/>

SELECT DISTINCT *
 WHERE
   { 
# ?s rdfs:subClassOf mondo:0005148 .
# ?s rdfs:label ?s_label .
   }
LIMIT 100
                """
        rr = self.triplestore.query_template(
            #inputs={'super': }, \
            outputs=['s', 's_label'], \
            template_text=text \
            )
        return rr

# %%
get_subclasses()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-bb97523dd13e> in <module>
# ----> 1 get_subclasses()
#
# <ipython-input-36-a03259f4bd88> in get_subclasses()
#      16 LIMIT 100
#      17             """
# ---> 18     rr = self.triplestore.query_template(
#      19         #inputs={'super': }, \
#      20         outputs=['s', 's_label'], \
#
# NameError: name 'self' is not defined
